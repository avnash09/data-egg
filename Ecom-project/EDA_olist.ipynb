# %% [markdown]
# # Olist Brazilian E-Commerce — Exploratory Data Analysis
#
# Imports all datasets and does a first-pass look at shape, dtypes, missing values, and how the tables join together.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
customers = pd.read_csv('olist_customers_dataset.csv')
geolocation = pd.read_csv('olist_geolocation_dataset.csv')
order_items = pd.read_csv('olist_order_items_dataset.csv', parse_dates=['shipping_limit_date'])
order_payments = pd.read_csv('olist_order_payments_dataset.csv')
order_reviews = pd.read_csv(
    'olist_order_reviews_dataset.csv',
    parse_dates=['review_creation_date', 'review_answer_timestamp']
)
orders = pd.read_csv(
    'olist_orders_dataset.csv',
    parse_dates=[
        'order_purchase_timestamp',
        'order_approved_at',
        'order_delivered_carrier_date',
        'order_delivered_customer_date',
        'order_estimated_delivery_date',
    ],
)
products = pd.read_csv('olist_products_dataset.csv')
sellers = pd.read_csv('olist_sellers_dataset.csv')
category_translation = pd.read_csv('product_category_name_translation.csv')

datasets = {
    'customers': customers,
    'geolocation': geolocation,
    'order_items': order_items,
    'order_payments': order_payments,
    'order_reviews': order_reviews,
    'orders': orders,
    'products': products,
    'sellers': sellers,
    'category_translation': category_translation,
}

# %% [markdown]
# ## Shape overview

# %%
pd.DataFrame(
    {name: [df.shape[0], df.shape[1]] for name, df in datasets.items()},
    index=['rows', 'columns'],
).T
# Out:
#                          rows  columns
# customers               99441        5
# geolocation           1000163        5
# order_items            112650        7
# order_payments         103886        5
# order_reviews           99224        7
# orders                  99441        8
# products                32951        9
# sellers                  3095        4
# category_translation       71        2

# %% [markdown]
# ## Dtypes and missing values per dataset

# %%
for name, df in datasets.items():
    print(f"=== {name} ===")
    display(df.dtypes.to_frame('dtype').join(df.isna().sum().to_frame('nulls')))
    print()
# Out:
# === customers ===
#                            dtype  nulls
# customer_id               object      0
# customer_unique_id        object      0
# customer_zip_code_prefix   int64      0
# customer_city             object      0
# customer_state            object      0
# === geolocation ===
#                                dtype  nulls
# geolocation_zip_code_prefix    int64      0
# geolocation_lat              float64      0
# geolocation_lng              float64      0
# geolocation_city              object      0
# geolocation_state             object      0
# === order_items ===
#                               dtype  nulls
# order_id                     object      0
# order_item_id                 int64      0
# product_id                   object      0
# seller_id                    object      0
# shipping_limit_date  datetime64[ns]      0
# price                       float64      0
# freight_value               float64      0
# === order_payments ===
# ...

# %% [markdown]
# ## Head of each table

# %%
for name, df in datasets.items():
    print(f"=== {name} ===")
    display(df.head(3))
# Out:
# === customers ===
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# === geolocation ===
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# ...

# %% [markdown]
# ## Duplicate rows / key uniqueness check

# %%
print('duplicate order_ids in orders:', orders['order_id'].duplicated().sum())
print('duplicate customer_ids in customers:', customers['customer_id'].duplicated().sum())
print('duplicate product_ids in products:', products['product_id'].duplicated().sum())
print('duplicate seller_ids in sellers:', sellers['seller_id'].duplicated().sum())
# Out:
# duplicate order_ids in orders: 0
# duplicate customer_ids in customers: 0
# duplicate product_ids in products: 0
# duplicate seller_ids in sellers: 0

# %% [markdown]
# ## Joining the core tables into one order-level frame
#
# `orders` → `order_items` → `products` (+ category translation) → `sellers`, plus `customers` and aggregated `order_payments`.

# %%
products_en = products.merge(category_translation, on='product_category_name', how='left')

order_full = (
    orders
    .merge(order_items, on='order_id', how='left')
    .merge(products_en, on='product_id', how='left')
    .merge(sellers, on='seller_id', how='left')
    .merge(customers, on='customer_id', how='left')
)

payments_agg = order_payments.groupby('order_id', as_index=False)['payment_value'].sum()
order_full = order_full.merge(payments_agg, on='order_id', how='left')

order_full.shape
# Out:
# (113425, 31)

# %%
order_full.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Quick numeric summary

# %%
order_full[['price', 'freight_value', 'payment_value']].describe()
# Out:
#                price  freight_value  payment_value
# count  112650.000000  112650.000000  113422.000000
# mean      120.653739      19.990320     180.482857
# std       183.633928      15.806405     273.548227
# min         0.850000       0.000000       0.000000
# 25%        39.900000      13.080000      65.680000
# 50%        74.990000      16.260000     114.400000
# 75%       134.900000      21.150000     195.360000
# max      6735.000000     409.680000   13664.080000

# %% [markdown]
# ## Order status breakdown

# %%
orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64
